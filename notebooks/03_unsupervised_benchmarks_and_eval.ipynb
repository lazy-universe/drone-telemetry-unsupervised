# %% [markdown]
# # 🛸 Unsupervised Evaluation, Benchmarks & Ablations
#
# This notebook evaluates the unsupervised models across cross-device OOD splits, per-attack subcategories, multi-model ensemble detection, and feature importance analyses.

# %% [markdown]
# ## 1. Setup Working Directory & Environment

# %%
from pathlib import Path
import os
import torch

PROJECT_ROOT = Path("..").resolve()
os.chdir(PROJECT_ROOT)
print("Operating Directory:", os.getcwd())
print(f"CUDA Available: {torch.cuda.is_available()}")

# %% [markdown]
# ## 2. Cross-Device OOD Benchmark
# Evaluates generalization to unseen drone airframes under the device split.

# %%
# !python presets/run_device_split_benchmark.py

# %% [markdown]
# ## 3. Sub-Attack Per-Class Detection Breakdown
# Evaluates detection accuracy across Real ESP32, Sim Easy, Sim Medium, Sim Geometry, and Sim Baseline attacks.

# %%
# !python presets/run_per_class_eval.py

# %% [markdown]
# ## 4. Multi-Model Ensemble Evaluation
# Evaluates logical OR / AND ensemble combination rules across classical and deep models.

# %%
# !python presets/run_ensemble_eval.py

# %% [markdown]
# ## 5. Feature Importance & Permutation Analysis
# Measures feature contribution and degradation impact when individual features are ablated or shuffled.

# %%
# !python presets/run_feature_importance.py
# !python presets/run_ablation.py

# %% [markdown]
# ## 6. Empirical Feature Value Ranges
# Computes exact minimum, maximum, mean, and standard deviation bounds across normal and spoofed flights.

# %%
# !python presets/compute_feature_bounds.py
